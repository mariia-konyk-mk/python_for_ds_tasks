# %% [markdown]
# # Вступ
# **Hello**-!-
#
# **Ця** програма робить *щось* корисне.

# %%
p=123
s=45
l=77
p+s/l
# Out:
# 123.58441558441558

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
print(n)
# Out:
# [163]

# %%
n = [1 + 14*2 + 3*52 + 4]

# %%
n
# Out:
# [189]

# %% [markdown]
# ## **Розділ 1**
# ##### Підрозділ
# ## *Розділ 2*

# %%
[x**3 for x in range(-7, 10)]
# Out:
# [-343, -216, -125, -64, -27, -8, -1, 0, 1, 8, 27, 64, 125, 216, 343, 512, 729]

# %%
p*l/s
# Out:
# 210.46666666666667
